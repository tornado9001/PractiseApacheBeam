# %% [markdown]
# This files is created for the ease of data analysis. Using this Jupyter notebook to understand some of the behaviour or pattern if the excel sheets.

# %%
## common library for data cleaning or analyse data
import pandas as pd
import numpy as np
import seaborn as sns


# print to hint you have completed the import of libraries
# if you dont see the message below, you may have to check your python lib
print("Hello World - you have successfully imported libraries!!")

## e.g.
# pip install pandas
#  pip install numpy
#  pip install seaborn
#  pip install matplotlib
# Out:
# Hello World - you have successfully imported libraries!!

# %% [markdown]
# My first loading of a csv file. Using pd to read and showing basic information as show in below code section.

# %%
arabica = pd.read_csv("../src/main/resources/data/arabica_data_cleaned.csv")

# explain the data info, in total should see columns described in "../src/main/resources/data/README.md"
arabica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1311 entries, 0 to 1310
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             1311 non-null   int64
#  1   Species                1311 non-null   object
#  2   Owner                  1304 non-null   object
#  3   Country.of.Origin      1310 non-null   object
#  4   Farm.Name              955 non-null    object
#  5   Lot.Number             270 non-null    object
#  6   Mill                   1001 non-null   object
#  7   ICO.Number             1163 non-null   object
#  8   Company                1102 non-null   object
#  9   Altitude               1088 non-null   object
#  10  Region                 1254 non-null   object
#  11  Producer               1081 non-null   object
#  12  Number.of.Bags         1311 non-null   int64
#  13  Bag.Weight             1311 non-null   object
# ...

# %%
# show the status of null value in cells.
arabica.isnull().sum()
# Out:
# Unnamed: 0                  0
# Species                     0
# Owner                       7
# Country.of.Origin           1
# Farm.Name                 356
# Lot.Number               1041
# Mill                      310
# ICO.Number                148
# Company                   209
# Altitude                  223
# Region                     57
# Producer                  230
# Number.of.Bags              0
# Bag.Weight                  0
# In.Country.Partner          0
# Harvest.Year               47
# Grading.Date                0
# Owner.1                     7
# Variety                   201
# Processing.Method         152
# Aroma                       0
# Flavor                      0
# Aftertaste                  0
# Acidity                     0
# Body                        0
# Balance                     0
# Uniformity                  0
# Clean.Cup                   0
# Sweetness                   0
# Cupper.Points               0
# Total.Cup.Points            0
# ...

# %% [markdown]
# Simple analyse column/cells with numeric data using pd.describe().

# %%
# show analytics result of those column with numeric value.
arabica.describe()
# Out:
#         Unnamed: 0  Number.of.Bags        Aroma       Flavor   Aftertaste  \
# count  1311.000000     1311.000000  1311.000000  1311.000000  1311.000000
# mean    656.000763      153.887872     7.563806     7.518070     7.397696
# std     378.598733      129.733734     0.378666     0.399979     0.405119
# min       1.000000        0.000000     0.000000     0.000000     0.000000
# 25%     328.500000       14.500000     7.420000     7.330000     7.250000
# 50%     656.000000      175.000000     7.580000     7.580000     7.420000
# 75%     983.500000      275.000000     7.750000     7.750000     7.580000
# max    1312.000000     1062.000000     8.750000     8.830000     8.670000
#
#            Acidity         Body      Balance   Uniformity   Clean.Cup  \
# count  1311.000000  1311.000000  1311.000000  1311.000000  1311.00000
# mean      7.533112     7.517727     7.517506     9.833394     9.83312
# std       0.381599     0.359213     0.406316     0.559343     0.77135
# ...

# %% [markdown]
# Analyse some of the unique value. We can have drop it if the column only have a single value, so that we can have less dimension when analyse.

# %%
# Loop each columns from arabica

for col in arabica.columns:
    print(f"{col} has {len(arabica[col].unique())} unique values")
# Out:
# Unnamed: 0 has 1311 unique values
# Species has 1 unique values
# Owner has 306 unique values
# Country.of.Origin has 37 unique values
# Farm.Name has 558 unique values
# Lot.Number has 222 unique values
# Mill has 448 unique values
# ICO.Number has 841 unique values
# Company has 271 unique values
# Altitude has 384 unique values
# Region has 344 unique values
# Producer has 676 unique values
# Number.of.Bags has 130 unique values
# Bag.Weight has 56 unique values
# In.Country.Partner has 27 unique values
# Harvest.Year has 47 unique values
# Grading.Date has 558 unique values
# Owner.1 has 310 unique values
# Variety has 30 unique values
# Processing.Method has 6 unique values
# Aroma has 33 unique values
# Flavor has 35 unique values
# Aftertaste has 35 unique values
# Acidity has 31 unique values
# Body has 31 unique values
# Balance has 32 unique values
# Uniformity has 10 unique values
# Clean.Cup has 11 unique values
# Sweetness has 8 unique values
# ...
